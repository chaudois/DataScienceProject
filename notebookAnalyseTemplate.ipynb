# %%
import pandas as pd
import numpy as np
import seaborn as sns

data=pd.read_csv('data.csv',dtype=str)

# %%
df=data.loc[::100,['r','m (kg)','Mt','Enedc (g/km)','Ewltp (g/km)','W (mm)','At1 (mm)','At2 (mm)','ec (cm3)','ep (KW)','z (Wh/km)','Erwltp (g/km)','Fuel consumption ','Electric range (km)']]

# %%
sns.heatmap(df.corr(),annot=True, cmap='RdBu_r', center=0)
# Out:
# <Axes: >

# %%
sns.scatterplot(df,x='m (kg)',y='Ewltp (g/km)')
# Out:
# <Axes: xlabel='m (kg)', ylabel='Ewltp (g/km)'>
